# %%
import serpapi
params = {
  "api_key": "API key",
  "engine": "google",
  "q": "money laundering",
#   "location": "Singapore",
  "google_domain": "google.com",
  "hl": "en",
  "tbm": "nws"
}

search = serpapi.GoogleSearch(params)

# %%
import pandas as pd
import time
from serpapi import GoogleSearch
import requests

SERP_API_KEY = "API key"

# Define your search queries for each category
search_config = [
  {
    "category": "Money Laundering",
    "search_queries": [
      "money laundering charges",
      "arrested for money laundering",
      "laundered funds",
      "money laundering network"
    ]
  },
  {
    "category": "Terrorist Financing",
    "search_queries": [
      "funding terrorism",
      "money trail terrorism",
      "financing extremist groups",
      "donations linked to terrorism"
    ]
  },
  {
    "category": "Sanctions Violations",
    "search_queries": [
      "sanctions breach",
      "bypassed sanctions",
      "trading with sanctioned entities",
      "UN/EU/OFAC sanctions violation"
    ]
  },
  {
    "category": "Fraud",
    "search_queries": [
      "financial fraud case",
      "bank fraud investigation",
      "wire fraud indictment",
      "fraudulent transactions"
    ]
  },
  {
    "category": "Tax Evasion",
    "search_queries": [
      "underreported income",
      "offshore tax evasion",
      "tax haven investigation",
      "illicit tax schemes"
    ]
  },
  {
    "category": "Bribery and Corruption",
    "search_queries": [
      "accused of corruption",
      "corruption investigation",
      "illegal kickbacks",
      "public official bribery"
    ]
  },
  {
    "category": "Insider Trading",
    "search_queries": [
      "trading on non-public information",
      "securities fraud case",
      "insider trading investigation",
      "market manipulation scheme"
    ]
  },
  {
    "category": "Ponzi and Pyramid Schemes",
    "search_queries": [
      "pyramid scheme charges",
      "investment scam",
      "high-return fraud",
      "ponzi fraud case"
    ]
  },
  {
    "category": "Trade-Based Money Laundering",
    "search_queries": [
      "over-invoicing scheme",
      "under-invoicing fraud",
      "illicit trade transactions",
      "false trade documents"
    ]
  }
]


# Store results
results = []

# Search each query
for config in search_config:
    category = config["category"]
    for query in config["search_queries"]:

        print(f"Searching: '{query}' under '{category}'")
        try:
            params = {
                "engine": "google_news",
                "q": query,
                "hl": "en",
                "api_key": SERP_API_KEY
            }

            search = GoogleSearch(params)
            news_results = search.get_dict().get("news_results", [])

            for article in news_results:
                results.append({
                    "category": category,
                    "query": query,
                    "title": article.get("title"),
                    "snippet": article.get("snippet"),
                    "source": article.get("source"),
                    "link": article.get("link"),
                    "date": article.get("date")
                })
            time.sleep(2)  # Respect rate limits
            

        except Exception as e:
            print(f"Error: {e}")
# Save to CSV
df = pd.DataFrame(results)
df.to_csv("serpapi_adverse_news.csv", index=False)
print(f"✅ Saved {len(df)} articles.")
# Out:
# Searching: 'money laundering charges' under 'Money Laundering'
# Searching: 'arrested for money laundering' under 'Money Laundering'
# Searching: 'laundered funds' under 'Money Laundering'
# Searching: 'money laundering network' under 'Money Laundering'
# Searching: 'funding terrorism' under 'Terrorist Financing'
# Searching: 'money trail terrorism' under 'Terrorist Financing'
# Searching: 'financing extremist groups' under 'Terrorist Financing'
# Searching: 'donations linked to terrorism' under 'Terrorist Financing'
# Searching: 'sanctions breach' under 'Sanctions Violations'
# Searching: 'bypassed sanctions' under 'Sanctions Violations'
# Searching: 'trading with sanctioned entities' under 'Sanctions Violations'
# Searching: 'UN/EU/OFAC sanctions violation' under 'Sanctions Violations'
# Searching: 'financial fraud case' under 'Fraud'
# Searching: 'bank fraud investigation' under 'Fraud'
# Searching: 'wire fraud indictment' under 'Fraud'
# ...

# %%
import pandas as pd
import time
from serpapi import GoogleSearch
import requests

SERP_API_KEY = "3cd2ab093f5b4ac6efa22032fbff2d8be82e39ee81385360df7d3e5e5a92bb32"  # Replace with your key

# Define your search config (shortened for demo — extend as needed)
queries = [
    "Prateek Gupta",
    "Macy's",
    "Simpson Thacher",
    "Dmitrii Ovsiannikov",
    "Bob Menendez's",
    "STMicroelectronics",
]

# Store results
results = []

# Search each query
for query in queries:

    print(f"Searching: '{query}'")
    try:
        params = {
            "engine": "google_news",
            "q": query,
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        search = GoogleSearch(params)
        news_results = search.get_dict().get("news_results", [])

        for article in news_results:
            results.append({
                "query": query,
                "title": article.get("title"),
                "source": article.get("source"),
                "link": article.get("link"),
                "date": article.get("date")
            })
        time.sleep(2)  # Respect rate limits
        

    except Exception as e:
        print(f"Error: {e}")
# Save to CSV
df = pd.DataFrame(results)
df.to_csv("serpapi_adverse_news_testcase.csv", index=False)
print(f"✅ Saved {len(df)} articles.")
# Out:
# Searching: 'Prateek Gupta'
# Searching: 'Macy's'
# Searching: 'Simpson Thacher'
# Searching: 'Dmitrii Ovsiannikov'
# Searching: 'Bob Menendez's'
# Searching: 'STMicroelectronics'
# ✅ Saved 511 articles.

# %%
queries = [
  "global financial news",
  "stock market today",
  "economic news updates",
  "financial markets update",
  "latest business news",
  "financial trends 2025",
  "corporate earnings reports",
  "investment news",
  "economic outlook 2025",
  "financial news analysis",
  "real estate market update",
  "cryptocurrency news",
  "central bank interest rate news",
  "stock market trends",
  "business mergers and acquisitions",
  "companies earnings announcement",
  "global trade news",
  "commodity price update",
  "currency market news",
  "venture capital funding news"
]
results = []
for query in queries:
    params = {
        "engine": "google_news",
        "q": query,
        "hl": "en",
        "api_key": SERP_API_KEY
    }
    search = GoogleSearch(params)
    news_results = search.get_dict().get("news_results", [])

    for article in news_results:
        results.append({
            "category": "General Fiancial News",
            "query": query,
            "title": article.get("title"),
            "snippet": article.get("snippet"),
            "source": article.get("source"),
            "link": article.get("link"),
            "date": article.get("date")
        })

df = pd.DataFrame(results)
df.to_csv("serpapi_general_news.csv", index=False)
print(f"✅ Saved {len(df)} articles.")
# Out:
# ✅ Saved 1964 articles.

# %%
from serpapi import GoogleSearch
params = {
        "q": "related:business Joe Anderson after:2025-03-12",
        "hl": "en",
        "api_key": SERP_API_KEY,
        "tbm": "nws",

    }
search = GoogleSearch(params)
news_results = search.get_dict().get("news_results", [])

# %%
search.get_dict()
# Out:
# {'search_metadata': {'id': '67f90036d25b9f7f013e1c3b',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/1723f2be946b1e2d/67f90036d25b9f7f013e1c3b.json',
#   'created_at': '2025-04-11 11:42:46 UTC',
#   'processed_at': '2025-04-11 11:42:46 UTC',
#   'google_url': 'https://www.google.com/search?q=related%3Abusiness+Joe+Anderson+after%3A2025-03-12&oq=related%3Abusiness+Joe+Anderson+after%3A2025-03-12&hl=en&tbm=nws&sourceid=chrome&ie=UTF-8',
#   'raw_html_file': 'https://serpapi.com/searches/1723f2be946b1e2d/67f90036d25b9f7f013e1c3b.html',
#   'total_time_taken': 1.83},
#  'search_parameters': {'engine': 'google',
#   'q': 'related:business Joe Anderson after:2025-03-12',
#   'google_domain': 'google.com',
#   'hl': 'en',
#   'device': 'desktop',
#   'tbm': 'nws'},
#  'search_information': {'query_displayed': 'related:business Joe Anderson after:2025-03-12',
#   'total_results': 22500,
#   'time_taken_displayed': 0.31,
# ...

# %%
adverse_df_1 = pd.read_csv("serpapi_adverse_news_1.csv")
adverse_df = pd.read_csv("serpapi_adverse_news.csv")
general_df = pd.read_csv("serpapi_general_news.csv")

news_df = pd.concat([adverse_df, adverse_df_1, general_df]).sample(frac=1).reset_index(drop=True)

# %%
import json
with open('money_laundering.json', 'w') as f:
    json.dump(search.get_dict()['news_results'], f)

# %%
search.get_dict()['serpapi_pagination']['next']
# Out:
# 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=money+laundering&start=10&tbm=nws'

# %%
requests.get("https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=money+laundering&start=40&tbm=nws&api_key=3cd2ab093f5b4ac6efa22032fbff2d8be82e39ee81385360df7d3e5e5a92bb32").json()
# Out:
# {'search_metadata': {'id': '67f618c6cd836eb972f3c44b',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/041889e8f7e90b16/67f618c6cd836eb972f3c44b.json',
#   'created_at': '2025-04-09 06:50:46 UTC',
#   'processed_at': '2025-04-09 06:50:46 UTC',
#   'google_url': 'https://www.google.com/search?q=money+laundering&oq=money+laundering&hl=en&tbm=nws&start=40&sourceid=chrome&ie=UTF-8',
#   'raw_html_file': 'https://serpapi.com/searches/041889e8f7e90b16/67f618c6cd836eb972f3c44b.html',
#   'total_time_taken': 0.69},
#  'search_parameters': {'engine': 'google',
#   'q': 'money laundering',
#   'google_domain': 'google.com',
#   'hl': 'en',
#   'start': 40,
#   'device': 'desktop',
#   'tbm': 'nws'},
#  'search_information': {'query_displayed': 'money laundering',
#   'total_results': 20500,
#   'page_number': 5,
#   'time_taken_displayed': 0.24,
#   'news_results_state': 'Results for exact spelling'},
#  'news_results': [{'position': 1,
# ...

# %%
requests.get(search.get_dict()['pagination']['next']).json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Documents/projects/Adverse-News-Screening/.conda/lib/python3.9/site-packages/requests/models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/Documents/projects/Adverse-News-Screening/.conda/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 7.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 7.5 MB/s eta 0:00:00a 0:00:01m
# ...

# %%
import pandas as pd
pd.DataFrame.from_dict(search)
# Out:
#                     0
# 0     search_metadata
# 1   search_parameters
# 2  search_information
# 3        news_results
# 4          pagination
# 5  serpapi_pagination

# %%
search['news_results']
# Out:
# [{'position': 1,
#   'link': 'https://abcnews.go.com/US/former-crypto-mogul-sam-bankman-fried-transferred-new/story?id=120236745',
#   'title': 'Former crypto mogul Sam Bankman-Fried transferred out of New York prison',
#   'source': 'ABC News',
#   'date': '1 week ago',
#   'snippet': 'The Bureau of Prisons has transferred former crypto mogul Sam Bankman-Fried out of a detention center in New York, sources familiar with the matter told ABC...',
#   'thumbnail': 'https://serpapi.com/searches/67f4a1811acb41b78b459cc3/images/1c0c1ea8d8d542111653194775ff6d4964cb61d38a19e3729fc67b2ac51c7ead.jpeg'},
#  {'position': 2,
#   'link': 'https://www.wsj.com/finance/regulation/sam-bankman-fried-moved-to-oklahoma-prison-transit-facility-5814f3f8',
#   'title': 'Sam Bankman-Fried Moved to Oklahoma Prison Transit Facility',
#   'source': 'WSJ',
#   'date': '1 week ago',
# ...

# %%
# !pip install worldnewsapi
# Out:
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 10.4 MB/s eta 0:00:00
# ...
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
# ...

# %%
import worldnewsapi
from worldnewsapi.rest import ApiException
from pprint import pprint

# Defining the host is optional and defaults to https://api.worldnewsapi.com
# See configuration.py for a list of all supported configuration parameters.
configuration = worldnewsapi.Configuration(
    host = "https://api.worldnewsapi.com"
)

# The client must configure the authentication and authorization parameters
# in accordance with the API server security policy.
# Examples for each auth method are provided below, use the example that
# satisfies your auth use case.

# Configure API key authorization: apiKey
configuration.api_key['apiKey'] = 'ebab354b42584d35aa1dabd17dc7fa0f'


with worldnewsapi.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = worldnewsapi.NewsApi(api_client)
    text = 'Sam Bankman-Fried' # str | The text to match in the news content (at least 3 characters, maximum 100 characters). By default all query terms are expected, you can use an uppercase OR to search for any terms, e.g. tesla OR ford. You can also exclude terms by putting a minus sign (-) in front of the term, e.g. tesla -ford. For exact matches just put your term in quotes, e.g. \"elon musk\". (optional)
    text_match_indexes = 'title' # str | If a \"text\" is given to search for, you can specify where this text is searched for. Possible values are title, content, or both separated by a comma. By default, both title and content are searched. (optional)
    source_country = 'us' # str | The ISO 3166 country code from which the news should originate. (optional)
    language = 'en' # str | The ISO 6391 language code of the news. (optional)
    min_sentiment = -0.8 # float | The minimal sentiment of the news in range [-1,1]. (optional)
    max_sentiment = 0.8 # float | The maximal sentiment of the news in range [-1,1]. (optional)
    earliest_publish_date = '' # str | The news must have been published after this date. (optional)
    latest_publish_date = '2025-04-08 16:12:35' # str | The news must have been published before this date. (optional)
    news_sources = 'https://bloomberg.com,https://www.reuters.com,https://www.ft.com,https://www.wsj.com' # str | A comma-separated list of news sources from which the news should originate. (optional)
    # authors = 'John Doe' # str | A comma-separated list of author names. Only news from any of the given authors will be returned. (optional)
    # categories = 'politics,sports' # str | A comma-separated list of categories. Only news from any of the given categories will be returned. Possible categories are politics, sports, business, technology, entertainment, health, science, lifestyle, travel, culture, education, environment, other. Please note that the filter might leave out news, especially in non-English languages. If too few results are returned, use the text parameter instead. (optional)
    # entities = 'ORG:Tesla,PER:Elon Musk' # str | Filter news by entities (see semantic types). (optional)
    # location_filter = '51.050407, 13.737262, 20' # str | Filter news by radius around a certain location. Format is \"latitude,longitude,radius in kilometers\". Radius must be between 1 and 100 kilometers. (optional)
    sort = 'publish-time' # str | The sorting criteria (publish-time). (optional)
    sort_direction = 'DESC' # str | Whether to sort ascending or descending (ASC or DESC). (optional)
    offset = 0 # int | The number of news to skip in range [0,100000] (optional)
    number = 100 # int | The number of news to return in range [1,100] (optional)

    try:
        # Search News
        api_response = api_instance.search_news(text=text, text_match_indexes=text_match_indexes, source_country=source_country, language=language, min_sentiment=min_sentiment, max_sentiment=max_sentiment, earliest_publish_date=earliest_publish_date, latest_publish_date=latest_publish_date, sort=sort, sort_direction=sort_direction, offset=offset, number=number)
        print("The response of NewsApi->search_news:\n")
        pprint(api_response)
    except Exception as e:
        print("Exception when calling NewsApi->search_news: %s\n" % e)
# Out:
# Exception when calling NewsApi->search_news: (400)
# Reason: Bad Request
# ...

# %%
json.loads(api_response.to_json())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 json.loads(api_response.to_json())
#
# NameError: name 'json' is not defined

# %%
import json
print(json.loads(api_response.to_json())['news'][0]['text'])
# Out:
# Sam Bankman-Fried — the disgraced crypto bro convicted for playing ringmaster to a multi-billion dollar fraud scheme — no longer shares a prison block with Sean "Diddy" Combs.
#
# Instead, he's being relegated to the flat lands of Oklahoma, at least for the time being, after appearing in an unapproved video interview with Tucker Carlson.
#
# The 33-year-old SBF famously went from trading billions of dollars' worth of cryptocurrency to peddling commissary ramen packs after a massive federal investigation uncovered rampant fraud perpetuated by his blockchain company, FTX. His sentence is 25 years followed by three years of supervised release, which began in March of 2024.
#
# The Wall Street Journal reports that SBF was awakened at 3 am from his cot in the Brooklyn Metropolitan Correctional Center and carted off to a facility in Oklahoma City, which typically serves as a holding place for incarcerated people in transit to their long-term destination.
#
# ...

# %%
api_response
# Out:
# SearchNews200Response(offset=0, number=100, available=9440, news=[SearchNews200ResponseNewsInner(summary='The sketch show mocked the president\'s tariffs, saying Make America Wealthy Again would be preceded by the best ever "Great Depression."', image='https://d.newsweek.com/en/full/2621830/donald-trump.jpg', sentiment=0.142, language='en', video=None, title="'SNL' Roasts Donald Trump's MAWA Tariffs—'Eating the Cats'", url='https://www.newsweek.com/snl-donald-trump-tariffs-cats-haiti-2055964', source_country='US', id=308213194, text='Saturday Night Live (SNL) roasted President Donald Trump\'s tariff speech with a callback to the rumors about Haitian immigrants eating pets in Springfield, Ohio, which made headlines before the election.Newsweek has contacted the White House via email for a response to the SNL skit.The ContextThe president announced on Wednesday that the U.S. would impose a 10-percent "baseline" tariff on virtually all imports and singled out roughly 60 countries for wh
# ...

# %%
with worldnewsapi.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = worldnewsapi.NewsApi(api_client)
    name = 'Wall Street' # str | The (partial) name of the source.

    try:
        # Search News Sources
        source_response = api_instance.search_news_sources(name)
        print("The response of NewsApi->search_news_sources:\n")
        pprint(source_response)
    except Exception as e:
        print("Exception when calling NewsApi->search_news_sources: %s\n" % e)
# Out:
# The response of NewsApi->search_news_sources:
#
# SearchNewsSources200Response(available=1, sources=[SearchNewsSources200ResponseSourcesInner(name='The Wall Street Journal – ΤΟ ΒΗΜΑ', url='https://www.tovima.gr', language='el')])

# %%
len(api_response.model_dump()['news'])
# Out:
# 6

# %%
import datetime
(datetime.date.today() - datetime.timedelta(days=30)).strftime('%Y-%m-%d')
# Out:
# '2025-03-09'

# %%
import requests

def get_top_news(news_date):
    url = f"https://api.worldnewsapi.com/top-news?source-country=us&language=en&date={news_date}"
    api_key = "ebab354b42584d35aa1dabd17dc7fa0f"

    headers = {
        'x-api-key': api_key
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        return response.json()
    else:
        return f"Error: {response.status_code}"

# %%
res = get_top_news('2025-04-09')

# %%
from src.news_collector import NewsCollector
from datetime import date, timedelta
start_date = date.today() - timedelta(days=30)
collector = NewsCollector()
query = "Harvesh Seegolam"
collector.search(query=query, earliest_publish_date=start_date.strftime('%Y-%m-%d'))
print(collector.result)
# Out:
# {'offset': 0, 'number': 10, 'available': 0, 'news': []}

# %%
import pprint
pprint.pprint(collector.result)
# Out:
# {'available': 4,
#  'news': [{'authors': ['Editor'],
#            'category': 'politics',
#            'id': 305375844,
#            'image': 'https://i.dailymail.co.uk/1s/2025/03/28/15/96677757-0-image-m-9_1743176057611.jpg',
#            'language': 'en',
#            'publish_date': '2025-03-28 16:05:41',
#            'sentiment': -1.0,
#            'source_country': 'GB',
#            'summary': 'Anderson, 67, told reporters he looked forward to '
#                       "'clearing my name' after 'four and a half years of "
#                       "hell'.",
#            'text': 'Access Denied\n'
#                    '\n'
#                    "You don't have permission to access "
#                    '"http://www.dailymail.co.uk/news/article-14547829/liverpool-mayor-joe-anderson-derek-hatton-court.html" '
#                    'on this server.\n'
#                    'Reference #18.54247e68.1743223467.2edf4f9d\n'
# ...

# %%
import json
with open('test_search_result.json', 'w') as f:
    json.dump(collector.result, f)

# %%
with open('test_search_result.json', 'r') as f:
    collector.result = json.load(f)

# %%
from GoogleNews import GoogleNews
googlenews = GoogleNews(start='03/11/2025')
googlenews.get_news("Joe Anderson")

# %%
googlenews.search('APPLE')

# %%
import datetime
(datetime.date.today() - datetime.timedelta(days=30)).strftime('%Y-%m-%d')
# Out:
# '2025-03-12'

# %%
url = "https://google.serper.dev/news"
payload = json.dumps({
"q": f"related:business Joe Anderson",
"num": 100,
'tbs': "qdr:m"
})
headers = {
'X-API-KEY': "979e2e88ce516df3af9da28596a96ca5dbabc84a",
'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"searchParameters":{"q":"related:business Joe Anderson","type":"news","num":100,"tbs":"qdr:m","engine":"google"},"news":[{"title":"Retirement Financial Group Strengthens Wealth Management Services with the Appointment of Joe Anderson","link":"https://myfox8.com/business/press-releases/ein-presswire/795018398/retirement-financial-group-strengthens-wealth-management-services-with-the-appointment-of-joe-anderson","snippet":"Anderson, Partner & Senior Wealth Manager, Brings Additional Depth to RFG's Commitment to Holistic Financial Planning and Wealth Management.","date":"3 weeks ago","source":"FOX8 WGHP","imageUrl":"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQeKzR0ASl8jHRs3MPvt-sL81lUl4nkYkwKu3dZD3h9TxiDNmuBBNzKMQj6Pw&s","position":1},{"title":"Brady Aune and Joe Anderson Safety Bill clears House in wake of deaths of teens clearing lake weed","link":"https://www.kare11.com/article/news/politics/brady-aune-joe-anderson-safety-bill-clears-house-minnesota/89-2af632ec-0c02-4881-
# ...

# %%
response.status_code
# Out:
# 200

# %%
len(response.json()['news'])
# Out:
# 12

# %%
with open('test_search_result.json', 'w') as f:
    json.dump(response.json(), f)

# %%
pprint.pprint(response.json()['news'])
# Out:
# [{'date': '3 weeks ago',
#   'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQeKzR0ASl8jHRs3MPvt-sL81lUl4nkYkwKu3dZD3h9TxiDNmuBBNzKMQj6Pw&s',
#   'link': 'https://myfox8.com/business/press-releases/ein-presswire/795018398/retirement-financial-group-strengthens-wealth-management-services-with-the-appointment-of-joe-anderson',
#   'position': 1,
#   'snippet': 'Anderson, Partner & Senior Wealth Manager, Brings Additional '
#              "Depth to RFG's Commitment to Holistic Financial Planning and "
#              'Wealth Management.',
#   'source': 'FOX8 WGHP',
#   'title': 'Retirement Financial Group Strengthens Wealth Management Services '
#            'with the Appointment of Joe Anderson'},
#  {'date': '1 week ago',
#   'imageUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQwZr_h_ZbG45DWKk9SqNRFGPPu1WKz9sexo7xkkd8VcPSNMlOxQfArh12dKQ&s',
# ...

# %%
texts = ["[title]" + x["title"] + " [snippet]" + x['snippet'] for x in response.json()['news']]
texts
# Out:
# ["[title]Brady Aune and Joe Anderson Safety Bill clears House in wake of deaths of teens clearing lake weed [snippet]A bill to regulate companies that clear lake weeds using scuba divers in the wake of two young men's deaths passed the Minnesota House.",
#  "[title]Retirement Financial Group Strengthens Wealth Management Services with the Appointment of Joe Anderson [snippet]Anderson, Partner & Senior Wealth Manager, Brings Additional Depth to RFG's Commitment to Holistic Financial Planning and Wealth Management.",
#  '[title]Arthur Andersen | Accounting Firm, Enron Scandal & Legacy [snippet]Arthur Andersen, Arthur Andersen LLP was one of the largest public accounting firms in the 1990s, with more than 85,000 employees operating in 84 countries.',
#  '[title]Former Liverpool Mayor Joe Anderson in court over corruption charges [snippet]The former mayor of Liverpool, Joe Anderson, has appeared in court over bribery and misconduct charges.',
# ...

# %%
print("\n".join(texts).strip())
# Out:
# [title]Brady Aune and Joe Anderson Safety Bill clears House in wake of deaths of teens clearing lake weed [snippet]A bill to regulate companies that clear lake weeds using scuba divers in the wake of two young men's deaths passed the Minnesota House.
# [title]Retirement Financial Group Strengthens Wealth Management Services with the Appointment of Joe Anderson [snippet]Anderson, Partner & Senior Wealth Manager, Brings Additional Depth to RFG's Commitment to Holistic Financial Planning and Wealth Management.
# [title]Arthur Andersen | Accounting Firm, Enron Scandal & Legacy [snippet]Arthur Andersen, Arthur Andersen LLP was one of the largest public accounting firms in the 1990s, with more than 85,000 employees operating in 84 countries.
# [title]Former Liverpool Mayor Joe Anderson in court over corruption charges [snippet]The former mayor of Liverpool, Joe Anderson, has appeared in court over bribery and misconduct charges.
# ...

# %%
print("You are an expert in extracting named entities from financial news. I will be providing a set of entities and some news articles containing [title] and [snippet], and you will need to extract the entities and group the same entities together."
                    "\n## Constraints"
                    "\n1. References to the same entity should be grouped together while all variations should be listed."
                    "\n2. The output should be in a parsable JSON format. "
                    "\n3. Only return the JSON output, nothing else. Do not include any other strings whatsoever, even it's for formatting."
                    "\n4. If multiple news articles are provided, the articles will be seperated by a newline character. Return multiple results nested in a list."
                    "\n5. Keep the output format consistent for all the articles provided and preserve the order of the articles."
                    "\n## Entities"
                    "\nCOMPANY, PERSON, FINANCIAL_INSTITUTION, REGULATORY_BODY, LEGAL_ACTION, ENFORCEMENT_ACTION, RISK_TERM, LOCATION, DATE, SANCTION_ENTITY, SECTOR, REGULATION")
# Out:
# You are an expert in extracting named entities from financial news. I will be providing a set of entities and some news articles containing [title] and [snippet], and you will need to extract the entities and group the same entities together.
# ## Constraints
# 1. References to the same entity should be grouped together while all variations should be listed.
# 2. The output should be in a parsable JSON format.
# 3. Only return the JSON output, nothing else. Do not include any other strings whatsoever, even it's for formatting.
# 4. If multiple news articles are provided, the articles will be seperated by a newline character. Return multiple results nested in a list.
# 5. Keep the output format consistent for all the articles provided and preserve the order of the articles.
# ## Entities
# COMPANY, PERSON, FINANCIAL_INSTITUTION, REGULATORY_BODY, LEGAL_ACTION, ENFORCEMENT_ACTION, RISK_TERM, LOCATION, DATE, SANCTION_ENTITY, SECTOR, REGULATION

# %%
from collections import defaultdict
entities = [{"entity_type":"PERSON","entity_name":"Joe Anderson","variations":["Joe Anderson","Mayor Joe Anderson","Former Mayor Joe Anderson","Ex Mayor Joe Anderson","Former Liverpool Mayor Joe Anderson"]},{"entity_type":"PERSON","entity_name":"Derek Hatton","variations":["Derek Hatton"]},{"entity_type":"PERSON","entity_name":"Brady Aune","variations":["Brady Aune"]},{"entity_type":"COMPANY","entity_name":"Arthur Andersen","variations":["Arthur Andersen","Arthur Andersen LLP"]},{"entity_type":"FINANCIAL_INSTITUTION","entity_name":"Retirement Financial Group","variations":["Retirement Financial Group","RFG"]},{"entity_type":"LOCATION","entity_name":"Minnesota","variations":["Minnesota"]},{"entity_type":"REGULATION","entity_name":"Safety Bill","variations":["Safety Bill"]},{"entity_type":"SECTOR","entity_name":"Accounting","variations":["Accounting"]},{"entity_type":"LEGAL_ACTION","entity_name":"Corruption Charges","variations":["Corruption Charges","Bribery Charges","Misconduct Charges","Operation Aloft"]},{"entity_type":"ENFORCEMENT_ACTION","entity_name":"Intellectual Property Enforcement","variations":["Intellectual Property Enforcement"]},{"entity_type":"REGULATORY_BODY","entity_name":"Liverpool City Council","variations":["Liverpool City Council"]},{"entity_type":"LEGAL_ACTION","entity_name":"Operation Aloft","variations":["Operation Aloft"]}]
entity_group = defaultdict(list)
for entity_dict in entities:
    entity_group[entity_dict["entity_type"]].append({
        "entity_name": entity_dict["entity_name"],
        "variations": entity_dict["variations"]
    })

# %%
entity_group
# Out:
# defaultdict(list,
#             {'PERSON': [{'entity_name': 'Joe Anderson',
#                'variations': ['Joe Anderson',
#                 'Mayor Joe Anderson',
#                 'Former Mayor Joe Anderson',
#                 'Ex Mayor Joe Anderson',
#                 'Former Liverpool Mayor Joe Anderson']},
#               {'entity_name': 'Derek Hatton', 'variations': ['Derek Hatton']},
#               {'entity_name': 'Brady Aune', 'variations': ['Brady Aune']}],
#              'COMPANY': [{'entity_name': 'Arthur Andersen',
#                'variations': ['Arthur Andersen', 'Arthur Andersen LLP']}],
#              'FINANCIAL_INSTITUTION': [{'entity_name': 'Retirement Financial Group',
#                'variations': ['Retirement Financial Group', 'RFG']}],
#              'LOCATION': [{'entity_name': 'Minnesota',
#                'variations': ['Minnesota']}],
#              'REGULATION': [{'entity_name': 'Safety Bill',
#                'variations': ['Safety Bill']}],
# ...

# %%
pprint.pprint(entities)
# Out:
# [{'entity_name': 'Joe Anderson',
#   'entity_type': 'PERSON',
#   'variations': ['Joe Anderson',
#                  'Mayor Joe Anderson',
#                  'Former Mayor Joe Anderson',
#                  'Ex Mayor Joe Anderson',
#                  'Former Liverpool Mayor Joe Anderson']},
#  {'entity_name': 'Derek Hatton',
#   'entity_type': 'PERSON',
#   'variations': ['Derek Hatton']},
#  {'entity_name': 'Brady Aune',
#   'entity_type': 'PERSON',
#   'variations': ['Brady Aune']},
#  {'entity_name': 'Arthur Andersen',
#   'entity_type': 'COMPANY',
#   'variations': ['Arthur Andersen', 'Arthur Andersen LLP']},
#  {'entity_name': 'Retirement Financial Group',
#   'entity_type': 'FINANCIAL_INSTITUTION',
#   'variations': ['Retirement Financial Group', 'RFG']},
#  {'entity_name': 'Minnesota',
#   'entity_type': 'LOCATION',
#   'variations': ['Minnesota']},
#  {'entity_name': 'Safety Bill',
#   'entity_type': 'REGULATION',
#   'variations': ['Safety Bill']},
# ...

# %%
s = """
```json
[
    {
        "COMPANY": [
            {
                "entity_name": "Retirement Financial Group",
                "variations": ["RFG", "Retirement Financial Group"]
            }
        ],
        "PERSON": [
            {
                "entity_name": "Joe Anderson",
                "variations": ["Joe Anderson", "Anderson"]
            }
        ],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [],
        "PROTENTIAL_CRIME": [],
        "LEGAL_ACTION": [],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": [],
        "SANCTION_ENTITY": [],
        "SECTOR": ["wealth management"],
        "REGULATION": []
    },
    {
        "COMPANY": [],
        "PERSON": [
            {
                "entity_name": "Joe Anderson",
                "variations": ["Joe Anderson"]
            },
            {
                "entity_name": "Brady Aune",
                "variations": ["Brady Aune"]
            }
        ],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [],
        "PROTENTIAL_CRIME": [],
        "LEGAL_ACTION": [],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": [
            {
                "entity_name": "Minnesota",
                "variations": ["Minnesota"]
            }
        ],
        "SANCTION_ENTITY": [],
        "SECTOR": [],
        "REGULATION": ["Safety Bill"]
    },
    {
        "COMPANY": [
            {
                "entity_name": "Arthur Andersen",
                "variations": ["Arthur Andersen", "Arthur Andersen LLP"]
            }
        ],
        "PERSON": [],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [],
        "PROTENTIAL_CRIME": [],
        "LEGAL_ACTION": [],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": [],
        "SANCTION_ENTITY": [],
        "SECTOR": ["accounting"],
        "REGULATION": []
    },
    {
        "COMPANY": [],
        "PERSON": [
            {
                "entity_name": "Joe Anderson",
                "variations": ["Joe Anderson"]
            },
            {
                "entity_name": "Derek Hatton",
                "variations": ["Derek Hatton"]
            }
        ],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [],
        "PROTENTIAL_CRIME": ["bribery", "misconduct"],
        "LEGAL_ACTION": ["court", "charges"],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": ["Liverpool"],
        "SANCTION_ENTITY": [],
        "SECTOR": [],
        "REGULATION": []
    },
    {
        "COMPANY": [],
        "PERSON": [
            {
                "entity_name": "Joe Anderson",
                "variations": ["Joe Anderson"]
            },
            {
                "entity_name": "Derek Hatton",
                "variations": ["Derek Hatton"]
            }
        ],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [],
        "PROTENTIAL_CRIME": ["bribery", "misconduct"],
        "LEGAL_ACTION": ["charges"],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": [],
        "SANCTION_ENTITY": [],
        "SECTOR": [],
        "REGULATION": []
    },
    {
        "COMPANY": [],
        "PERSON": [
            {
                "entity_name": "Joe Anderson",
                "variations": ["Joe Anderson"]
            }
        ],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [],
        "PROTENTIAL_CRIME": ["corruption"],
        "LEGAL_ACTION": ["charges"],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": ["Liverpool"],
        "SANCTION_ENTITY": [],
        "SECTOR": [],
        "REGULATION": []
    },
    {
        "COMPANY": [],
        "PERSON": [],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [],
        "PROTENTIAL_CRIME": [],
        "LEGAL_ACTION": [],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": [],
        "SANCTION_ENTITY": [],
        "SECTOR": [],
        "REGULATION": []
    },
    {
        "COMPANY": [],
        "PERSON": [
            {
                "entity_name": "Derek Hatton",
                "variations": ["Derek Hatton"]
            }
        ],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [],
        "PROTENTIAL_CRIME": ["bribing", "procuring"],
        "LEGAL_ACTION": [],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": ["Liverpool"],
        "SANCTION_ENTITY": [],
        "SECTOR": [],
        "REGULATION": []
    },
    {
        "COMPANY": [],
        "PERSON": [
            {
                "entity_name": "Joe Anderson",
                "variations": ["Joe Anderson"]
            }
        ],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [],
        "PROTENTIAL_CRIME": ["corruption"],
        "LEGAL_ACTION": ["probe", "charges"],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": ["Liverpool"],
        "SANCTION_ENTITY": [],
        "SECTOR": [],
        "REGULATION": []
    },
    {
        "COMPANY": [],
        "PERSON": [
            {
                "entity_name": "Joe Anderson",
                "variations": ["Joe Anderson"]
            }
        ],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [],
        "PROTENTIAL_CRIME": ["threatening letters", "corruption"],
        "LEGAL_ACTION": ["charges"],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": ["Liverpool"],
        "SANCTION_ENTITY": [],
        "SECTOR": [],
        "REGULATION": []
    },
    {
        "COMPANY": [],
        "PERSON": [],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [
            {
                "entity_name": "Government imposed Commissioners",
                "variations": ["Government imposed Commissioners"]
            }
        ],
        "PROTENTIAL_CRIME": ["pervasive and rotten culture"],
        "LEGAL_ACTION": [],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": ["Liverpool"],
        "SANCTION_ENTITY": [],
        "SECTOR": [],
        "REGULATION": []
    },
    {
        "COMPANY": [],
        "PERSON": [
            {
                "entity_name": "Joe Anderson",
                "variations": ["Joe Anderson"]
            },
            {
                "entity_name": "Nick Kavanagh",
                "variations": ["Nick Kavanagh"]
            }
        ],
        "FINANCIAL_INSTITUTION": [],
        "REGULATORY_BODY": [],
        "PROTENTIAL_CRIME": [],
        "LEGAL_ACTION": ["charges"],
        "ENFORCEMENT_ACTION": [],
        "LOCATION": ["Liverpool"],
        "SANCTION_ENTITY": [],
        "SECTOR": [],
        "REGULATION": ["Operation Aloft"]
    }
]
```
"""

# %%
s.strip('`').strip("json")
# Out:
# '\n```json\n[\n    {\n        "COMPANY": [\n            {\n                "entity_name": "Retirement Financial Group",\n                "variations": ["RFG", "Retirement Financial Group"]\n            }\n        ],\n        "PERSON": [\n            {\n                "entity_name": "Joe Anderson",\n                "variations": ["Joe Anderson", "Anderson"]\n            }\n        ],\n        "FINANCIAL_INSTITUTION": [],\n        "REGULATORY_BODY": [],\n        "PROTENTIAL_CRIME": [],\n        "LEGAL_ACTION": [],\n        "ENFORCEMENT_ACTION": [],\n        "LOCATION": [],\n        "SANCTION_ENTITY": [],\n        "SECTOR": ["wealth management"],\n        "REGULATION": []\n    },\n    {\n        "COMPANY": [],\n        "PERSON": [\n            {\n                "entity_name": "Joe Anderson",\n                "variations": ["Joe Anderson"]\n            },\n            {\n                "entity_name": "Brady Aune",\n                "variations": ["Brady Aune"]\n            }\n        ]
# ...

# %%
json.loads(s.strip().strip('`').strip("json"))
# Out:
# [{'COMPANY': [{'entity_name': 'Retirement Financial Group',
#     'variations': ['RFG', 'Retirement Financial Group']}],
#   'PERSON': [{'entity_name': 'Joe Anderson',
#     'variations': ['Joe Anderson', 'Anderson']}],
#   'FINANCIAL_INSTITUTION': [],
#   'REGULATORY_BODY': [],
#   'PROTENTIAL_CRIME': [],
#   'LEGAL_ACTION': [],
#   'ENFORCEMENT_ACTION': [],
#   'LOCATION': [],
#   'SANCTION_ENTITY': [],
#   'SECTOR': ['wealth management'],
#   'REGULATION': []},
#  {'COMPANY': [],
#   'PERSON': [{'entity_name': 'Joe Anderson', 'variations': ['Joe Anderson']},
#    {'entity_name': 'Brady Aune', 'variations': ['Brady Aune']}],
#   'FINANCIAL_INSTITUTION': [],
#   'REGULATORY_BODY': [],
#   'PROTENTIAL_CRIME': [],
#   'LEGAL_ACTION': [],
#   'ENFORCEMENT_ACTION': [],
#   'LOCATION': [{'entity_name': 'Minnesota', 'variations': ['Minnesota']}],
#   'SANCTION_ENTITY': [],
#   'SECTOR': [],
#   'REGULATION': ['Safety Bill']},
#  {'COMPANY': [{'entity_name': 'Arthur Andersen',
# ...
